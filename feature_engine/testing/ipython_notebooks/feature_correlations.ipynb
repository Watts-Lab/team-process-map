# %%
import numpy as np
import pandas as pd

# %%
jury_features = pd.read_csv('../../output/jury_output_chat_level.csv')
csop_features = pd.read_csv('../../output/csop_output_chat_level.csv')

# %% [markdown]
# # Hedge (Naive) versus Hedge (ConvoKit)

# %%
jury_features['hedge_naive'].corr(jury_features['hashedge'])
# Out:
# 0.2308574671810889

# %%
csop_features['hedge_naive'].corr(csop_features['hashedge'])
# Out:
# 0.26939237818901485

# %% [markdown]
# ## What about the two versions of hedge within ConvoKit -- `hedges` and `hashedge`?

# %%
jury_features['hedges'].corr(jury_features['hashedge'])
# Out:
# 0.722934239533491

# %%
csop_features['hedges'].corr(csop_features['hashedge'])
# Out:
# 0.7551370070460546

# %% [markdown]
# # Positive and Negative Lexical Features v. ConvoKit

# %%
jury_features['positive_affect'].corr(jury_features['haspositive'])
# Out:
# 0.5380263885051804

# %%
jury_features['negative_affect'].corr(jury_features['hasnegative'])
# Out:
# 0.5005218900154254

# %%
csop_features['positive_affect'].corr(csop_features['haspositive'])
# Out:
# 0.6872412881952535

# %%
csop_features['negative_affect'].corr(csop_features['hasnegative'])
# Out:
# 0.3066585122990574

# %% [markdown]
# ## Positive and Negative Features v. BERT

# %%
jury_features['positive_affect'].corr(jury_features['positive_bert'])
# Out:
# 0.23508646504003952

# %%
csop_features['positive_affect'].corr(csop_features['positive_bert'])
# Out:
# 0.5274633850100329

# %%
jury_features['negative_affect'].corr(jury_features['negative_bert'])
# Out:
# 0.25043263199957316

# %%
csop_features['negative_affect'].corr(csop_features['negative_bert'])
# Out:
# 0.2766732922182337

# %% [markdown]
# ## ConvoKit Positivity v. BERT Positivity

# %%
csop_features['haspositive'].corr(csop_features['positive_bert'])
# Out:
# 0.5422519879464854

# %%
csop_features['hasnegative'].corr(csop_features['negative_bert'])
# Out:
# 0.515348556004903

# %%
jury_features['haspositive'].corr(jury_features['positive_bert'])
# Out:
# 0.10701809820708663

# %%
jury_features['hasnegative'].corr(jury_features['negative_bert'])
# Out:
# 0.3880114598259002

# %% [markdown]
# ## Positive / Negative wordcounts v. BERT

# %%
jury_features['positivity_wordcount'].corr(jury_features['positive_bert'])
# Out:
# 0.3700585949477598

# %%
csop_features['positivity_wordcount'].corr(csop_features['positive_bert'])
# Out:
# 0.29794710898594756

# %% [markdown]
# # Question versus Convokit Question
#
# [Note: we also have a more advanced NLTK question, but it's not yet merged into Main for some reason --- need to ask Yuluan!]

# %%
csop_features['num_question_naive'].corr(csop_features['direct_question'])
# Out:
# 0.29473624113192615

# %%
jury_features['num_question_naive'].corr(jury_features['direct_question'])
# Out:
# 0.40672332022371604

# %% [markdown]
# # First Person

# %%
csop_features['first_person'].corr(csop_features['1st_person'])
# Out:
# 0.45774934073066326

# %%
jury_features['first_person'].corr(jury_features['1st_person'])
# Out:
# 0.6126576085630873
